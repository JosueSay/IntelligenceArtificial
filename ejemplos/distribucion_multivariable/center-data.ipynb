# %% [markdown]
# # <center> **Centrado y Normalizado de Datos** </center>
# ## <font size=4> **Inteligencia Artificial 2025** </font> <font color=gray size=4> -- Alan Reyes-Figueroa </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd                # trabajar bases de datos (DataFrame)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read data

# %%
df = sns.load_dataset('penguins')       # importar el conjunto de datos

# %%
df.shape
# Out:
# (344, 7)

# %% [markdown]
# ## DataFrame exploration

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df = df.dropna()

# %%
data = df[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]
data
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [333 rows x 4 columns]

# %%
X = data.values
X
# Out:
# array([[  39.1,   18.7,  181. , 3750. ],
#        [  39.5,   17.4,  186. , 3800. ],
#        [  40.3,   18. ,  195. , 3250. ],
#        ...,
#        [  50.4,   15.7,  222. , 5750. ],
#        [  45.2,   14.8,  212. , 5200. ],
#        [  49.9,   16.1,  213. , 5400. ]], shape=(333, 4))

# %%
X.shape
# Out:
# (333, 4)

# %%
mu = X.mean(axis=0)
mu
# Out:
# array([  43.99279279,   17.16486486,  200.96696697, 4207.05705706])

# %%
sig = X.std(axis=0)
sig
# Out:
# array([  5.46045096,   1.96627643,  13.99470477, 804.00586016])

# %%
# centered data
Xc = X - mu

# normalized data
Xn = (X - mu) / sig

# %%
Xc.mean(axis=0)
# Out:
# array([ 2.04841149e-15,  1.02420575e-15,  2.04841149e-15, -8.73988903e-14])

# %%
Xn.std(axis=0)
# Out:
# array([1., 1., 1., 1.])

# %%
np.round(Xn, 5)
# Out:
# array([[-0.89604,  0.78073, -1.42675, -0.56847],
#        [-0.82279,  0.11958, -1.06947, -0.50629],
#        [-0.67628,  0.42473, -0.42637, -1.19036],
#        ...,
#        [ 1.17338, -0.74499,  1.50293,  1.91907],
#        [ 0.22108, -1.20271,  0.78837,  1.23499],
#        [ 1.08182, -0.54156,  0.85983,  1.48375]], shape=(333, 4))

# %%
Xn
# Out:
# array([[-0.89604189,  0.7807321 , -1.42675157, -0.56847478],
#        [-0.82278787,  0.11958397, -1.06947358, -0.50628618],
#        [-0.67627982,  0.42472926, -0.42637319, -1.1903608 ],
#        ...,
#        [ 1.17338426, -0.74499437,  1.50292796,  1.91906927],
#        [ 0.22108196, -1.20271231,  0.78837197,  1.23499466],
#        [ 1.08181673, -0.54156417,  0.85982757,  1.48374906]],
#       shape=(333, 4))

# %%
data_centered   = pd.DataFrame(data=Xc, columns=data.columns)
data_normalized = pd.DataFrame(data=Xn, columns=data.columns)

# %%
data_centered
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0         -4.892793       1.535135         -19.966967  -457.057057
# 1         -4.492793       0.235135         -14.966967  -407.057057
# 2         -3.692793       0.835135          -5.966967  -957.057057
# 3         -7.292793       2.135135          -7.966967  -757.057057
# 4         -4.692793       3.435135         -10.966967  -557.057057
# ..              ...            ...                ...          ...
# 328        3.207207      -3.464865          13.033033   717.942943
# 329        2.807207      -2.864865          14.033033   642.942943
# 330        6.407207      -1.464865          21.033033  1542.942943
# 331        1.207207      -2.364865          11.033033   992.942943
# 332        5.907207      -1.064865          12.033033  1192.942943
#
# [333 rows x 4 columns]

# %%
data_normalized
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0         -0.896042       0.780732          -1.426752    -0.568475
# 1         -0.822788       0.119584          -1.069474    -0.506286
# 2         -0.676280       0.424729          -0.426373    -1.190361
# 3         -1.335566       1.085877          -0.569284    -0.941606
# 4         -0.859415       1.747026          -0.783651    -0.692852
# ..              ...            ...                ...          ...
# 328        0.587352      -1.762145           0.931283     0.892957
# 329        0.514098      -1.457000           1.002739     0.799674
# 330        1.173384      -0.744994           1.502928     1.919069
# 331        0.221082      -1.202712           0.788372     1.234995
# 332        1.081817      -0.541564           0.859828     1.483749
#
# [333 rows x 4 columns]

# %%
plt.figure(figsize=(5,5))
sns.pairplot(data=data, diag_kind='kde')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.pairplot(data=data_centered, diag_kind='kde')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.pairplot(data=data_normalized, diag_kind='kde')
plt.show()

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data.iloc[:,:-1].boxplot()
# Out:
# <Axes: >

# %%
data_centered.boxplot()
# Out:
# <Axes: >

# %%
data_normalized.boxplot()
# Out:
# <Axes: >
